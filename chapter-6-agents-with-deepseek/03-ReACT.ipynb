# %%
import os
from openai import OpenAI
import httpx

import inspect
from pprint import pprint
from diskcache import Cache
from pydantic import BaseModel, Field

from typing import Any
from typing import Literal
import jupyter_black
import json
import requests
import requests
from markdownify import markdownify as md

jupyter_black.load()

DEEPSEEK_API_KEY = os.environ["DEEPSEEK_API_KEY"]
DEEPSEEK_BASE_URL = "https://api.deepseek.com"
MODEL = "deepseek-chat"
cache = Cache("./cache")
client = OpenAI(api_key=DEEPSEEK_API_KEY, base_url=DEEPSEEK_BASE_URL)

# %%
def to_openai_tool(func: callable) -> dict[str, Any]:
    sig = inspect.signature(func)
    if sig.parameters:
        param = next(iter(sig.parameters.values()))
        param_type = param.annotation
        schema = param_type.model_json_schema()
    else:
        param_type = None
        schema = {"type": "object", "properties": {}, "required": []}

    return {
        "type": "function",
        "function": {
            "name": func.__name__,
            "description": (param_type.__doc__ if param_type else func.__doc__ or ""),
            "parameters": schema,
        },
    }


@cache.memoize()
def llm_call(
    messages: list[dict[str, str]], tools: list[dict[str, Any]], model: str
) -> str:
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        tools=tools if tools else None,
        temperature=0.0,
        tool_choice="auto",
    )
    return response.choices[0].message

# %%
# get current weather
class GetWeather(BaseModel):
    latitude: float
    longitude: float
    temperature_unit: Literal["celsius", "fahrenheit"]


def get_current_weather(data: GetWeather) -> str:
    """Get the current weather in a given location."""
    resp = requests.get(
        "https://api.open-meteo.com/v1/forecast",
        params={
            "latitude": data.latitude,
            "longitude": data.longitude,
            "temperature_unit": data.temperature_unit,
            "current_weather": True,
        },
    )
    return json.dumps(resp.json())


# get current location
def get_current_location() -> str:
    return json.dumps(requests.get("http://ip-api.com/json?fields=lat,lon").json())


# calculate
class Calculate(BaseModel):
    formula: str = Field(
        description="Numerical expression to compute the result of, in Python syntax."
    )


def calculate(
    data: Calculate,
) -> str:
    """Calculate the result of a given formula."""
    return str(eval(data.formula))


TOOLS = [
    to_openai_tool(get_current_weather),
    to_openai_tool(get_current_location),
    to_openai_tool(calculate),
]
FUNC_TYPES = {
    get_current_weather: GetWeather,
    get_current_location: None,
    calculate: Calculate,
}

# %%
class ReACTAgent:
    def __init__(
        self,
        system: str = "",
        model: str = "deepseek-chat",
        tools: list[dict[str, Any]] | None = None,
        max_iters: int = 10,
    ):
        self.model = model
        self.tools = tools or []
        self.messages: list[dict[str, str]] = []
        if system:
            self.messages.append({"role": "system", "content": system})

        self.max_iters = max_iters

    def __call__(self, content: str) -> str:
        self.messages.append({"role": "user", "content": content})

        iterations = 0
        while True:
            iterations += 1
            message = self._send()
            self.messages.append(message)

            tool_calls = getattr(message, "tool_calls", None)
            if not tool_calls:
                return message.content

            for call in tool_calls:
                func = globals()[call.function.name]
                args_model = FUNC_TYPES[func]
                args = (
                    args_model.model_validate_json(call.function.arguments)
                    if call.function.arguments != "{}"
                    else None
                )
                print(f"** CALLING FUNCTION {func.__name__} **")
                print(f"*** ARGS ***\n{args}\n")

                result = func(args) if args else func()
                print(f"*** RESULT ***\n{result}\n***")

                self.messages.append(
                    {
                        "role": "tool",
                        "tool_call_id": call.id,
                        "content": result,
                    }
                )

            if iterations >= self.max_iters:
                raise Exception("Max iterations reached")

    def _send(self):
        return llm_call(self.messages, self.tools, self.model)

# %%
system_prompt = """
You are a helpful assistant who can answer multistep questions by sequentially calling functions. 

Follow a pattern of:
- THOUGHT (reason step-by-step about which function to call next)
- ACTION (call a function as a next step towards the final answer) 
- OBSERVATION (output of the function)

Reason step by step which actions to take to get to the answer. 

Only call functions with arguments coming verbatim from the user or the output of other functions.
"""

# question = "What's the current weather for my location? Give me the temperature in degrees Celsius and the wind speed in knots."
# bot = ReACTAgent(system=system_prompt, tools=TOOLS)
# response = bot(question)
# print("Response:", response)

# %%
class SearchWeb(BaseModel):
    """Search the web for a given query."""

    query: str
    max_results: int = 10


def search_web(data: SearchWeb) -> str:
    url = "https://api.marginalia.nu/{key}/search/{query}"
    rsp = httpx.get(url.format(key="public", query=data.query)).json()

    return str(rsp["results"][: data.max_results])


class ReadWebsite(BaseModel):
    """Read the content of a website and return it as text. (useful for further research)"""

    url: str


def read_website(data: ReadWebsite) -> str:

    html_content = requests.get(data.url).text
    return md(html_content)


TOOLS = [
    to_openai_tool(search_web),
    to_openai_tool(read_website),
]
FUNC_TYPES = {
    search_web: SearchWeb,
    read_website: ReadWebsite,
}

# %%
question = "What is the population of the city of Ancona?"

bot = ReACTAgent(
    system=system_prompt, tools=TOOLS
)  # model="deepseek-reasoner") Add support for this.
response = bot(question)
print("Response:", response)
# Out:
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='population of Ancona Italy 2023' max_results=10
#
# *** RESULT ***
# [{'url': 'https://savvysciencepublisher.com/jms/index.php/jppr/article/view/1031', 'title': 'Which Is The Role of Social Media in Web-Based Adolescent NonSuicidal Self-Injury (NSSI)?\n\t\t\t\t\t\t\t| Journal of Psychology and ...', 'description': 'Adolescent, Adolescence, Deliberate Self-Harm (DSH Non-suicidal Self-injuries (NSSI Self-harm, Social Media, Web In recent years, there has been a significant surge in non-suicidal self-injury (NSSI)-related content on the Internet. In fact, the technolog', 'quality': 6.551828672946033, 'format': 'html', 'details': [[]]}, {'url': 'https://en.wikipedia.org/wiki/List_of_mayors_of_Ancona', 'title': 'List of mayors of Ancona', 'description': "The Mayor of Ancona is an elected politician who, along with the Ancona's City Council, is accountable for the strategic government of Ancona in Marche, Italy. The current Mayor is Daniele Silvetti, a member of Forza Italia who took office on 30 May 2023.", 'quality': 6.698632502359717, 'format': 'html', 'details': [[]]}, {'url': 'https://www.faunalia.eu/en/intro/cv_pc', 'title': 'Curriculum Vitae of Paolo Cavallini | Faunalia', 'description': 'Date of birth: 27/10/1963 Address: Piazza Garibaldi 4, 56025 Pontedera (PI) Phone 39-348-3801953 e-mail: cavallini@faunalia.it C.F CVLPLA63R27G843A 1994 Doctorate in Zoology (University of Siena, Italy Title of the thesis: Variations in the biology of the', 'quality': 7.628848863705134, 'format': 'html', 'details': [[]]}, {'url': 'https://ard.bmj.com/content/early/2024/10/17/ard-2024-226430', 'title': 'EULAR recommendations for the treatment of systemic sclerosis: 2023 update | Annals of the Rheumatic Diseases', 'description': 'Article Text Recommendation EULAR recommendations for the treatment of systemic sclerosis: 2023 update Objectives To update the 2017 European Alliance of Associations for Rheumatology (EULAR) recommendations for treatment of systemic sclerosis (SSc incorp', 'quality': 8.438684508620467, 'format': 'html', 'details': [[]]}, {'url': 'https://www.iss.it/documents/20126/0/Libro+annali+3_2023.pdf/f19a9667-351c-24d3-2be9-5c8712479918?t=1694710297612', 'title': 'Annali DELL’ISTITUTO SUPERIORE DI SANITÀ', 'description': '177 Ann Ist Super Sanità 2023 Vol. 59, No. 3: 177-179 DOI: 10.4415/ANN_23_03_01 1Servizio Comunicazione Scientifica, Istituto Superiore di Sanit Rome, Italy 2Formerly Director, Centro di Riferimento per le Scienze Comportamentali e la Salute Mentale, Isti', 'quality': 8.461047024082971, 'format': 'pdf', 'details': [[]]}, {'url': 'https://www.iss.it/documents/20126/0/ANNALI+1-2023.pdf/9a649545-d15f-878b-44bf-14b19df00ae1?t=1679324385840', 'title': 'Annali DELL’ISTITUTO SUPERIORE DI SANITÀ', 'description': '2 Domenica Taruscio and Andrea Piccioli establish the procedures for collecting and delivering and regional levels of governance and expertise. blood samples to screening centres Assessment and review: data collection and the flow define the catchment are', 'quality': 8.817011251038048, 'format': 'pdf', 'details': [[]]}, {'url': 'https://www.cruisemapper.com/ports/ancona-port-243', 'title': 'Ancona (Italy) cruise port schedule | CruiseMapper', 'description': "Port Ancona cruise ship schedule shows timetable calendars of all arrival and departure dates by month. The port's schedule lists all ships (in links) with cruises going to or leaving from Ancona, Italy. To see the full itineraries (ports of call dates an", 'quality': 8.99811119814034, 'format': 'html', 'details': [[]]}, {'url': 'https://www.toms.com.hr/index.php/toms/article/download/718/591/5704', 'title': 'The Evolution of Italy-Greece Passenger Maritime Transport: a Multi-level Study to Estimate the Factors Influencing the Deman...', 'description': 'In recent years, the shipping and maritime transport segment has undergone profound changes. Faced with the need to achieve the sustainability goals set by Agenda 2030, different sustainable modes of transport must therefore be evaluated. Passenger transp', 'quality': 9.03 ...
# ***
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='Ancona Italy population 2023' max_results=10
#
# *** RESULT ***
# [{'url': 'https://en.wikipedia.org/wiki/List_of_mayors_of_Ancona', 'title': 'List of mayors of Ancona', 'description': "The Mayor of Ancona is an elected politician who, along with the Ancona's City Council, is accountable for the strategic government of Ancona in Marche, Italy. The current Mayor is Daniele Silvetti, a member of Forza Italia who took office on 30 May 2023.", 'quality': 6.295423872601846, 'format': 'html', 'details': [[]]}, {'url': 'https://en.wikipedia.org/wiki/Central_Italy', 'title': 'Central Italy', 'description': 'Central Italy (Italian Italia centrale or Centro Italia is one of the five official statistical regions of Italy used by the National Institute of Statistics (ISTAT a first-level NUTS region, and a European Parliament constituency. Central Italy encompass', 'quality': 6.302984976908197, 'format': 'html', 'details': [[]]}, {'url': 'https://www.faunalia.eu/en/intro/cv_pc', 'title': 'Curriculum Vitae of Paolo Cavallini | Faunalia', 'description': 'Date of birth: 27/10/1963 Address: Piazza Garibaldi 4, 56025 Pontedera (PI) Phone 39-348-3801953 e-mail: cavallini@faunalia.it C.F CVLPLA63R27G843A 1994 Doctorate in Zoology (University of Siena, Italy Title of the thesis: Variations in the biology of the', 'quality': 7.36043910896542, 'format': 'html', 'details': [[]]}, {'url': 'https://www.davestravelpages.com/patras-port-in-greece/', 'title': 'Patras Ferry Port in Greece - Ferries to Ionian Islands and Italy', 'description': 'The New Port of Patras in Greece acts as a gateway for ferries traveling to and from Italy and other Adriatic destinations. It is also a convenient port for domestic ferries to and from the Greek islands of Kefalonia and Ithaca. This guide to Patras port ', 'quality': 7.419983550720475, 'format': 'html', 'details': [[]]}, {'url': 'https://www.iss.it/documents/20126/0/Libro+annali+3_2023.pdf/f19a9667-351c-24d3-2be9-5c8712479918?t=1694710297612', 'title': 'Annali DELL’ISTITUTO SUPERIORE DI SANITÀ', 'description': '177 Ann Ist Super Sanità 2023 Vol. 59, No. 3: 177-179 DOI: 10.4415/ANN_23_03_01 1Servizio Comunicazione Scientifica, Istituto Superiore di Sanit Rome, Italy 2Formerly Director, Centro di Riferimento per le Scienze Comportamentali e la Salute Mentale, Isti', 'quality': 8.14369419502448, 'format': 'pdf', 'details': [[]]}, {'url': 'https://www.iss.it/documents/20126/0/ANNALI+1-2023.pdf/9a649545-d15f-878b-44bf-14b19df00ae1?t=1679324385840', 'title': 'Annali DELL’ISTITUTO SUPERIORE DI SANITÀ', 'description': '2 Domenica Taruscio and Andrea Piccioli establish the procedures for collecting and delivering and regional levels of governance and expertise. blood samples to screening centres Assessment and review: data collection and the flow define the catchment are', 'quality': 8.491566572274493, 'format': 'pdf', 'details': [[]]}, {'url': 'https://exarc.net/issue-2023-2/mm/rearrangement-archaeological-museum-arcevia-aiming-improve-accessibility', 'title': 'The Rearrangement of the Archaeological Museum of Arcevia: Aiming to Improve Accessibility | The EXARC Journal', 'description': 'The content is published under a Creative Commons Attribution Non-Commercial 4.0 License. Persistent Identifier https exarc.net/ark:/88735/10685 Publication Date 2023-06-17 Author(s) Mauro Fiorentini Independent researcher. via Tancredi 3, 60128 Ancona (A', 'quality': 8.49417191940084, 'format': 'html', 'details': [[]]}, {'url': 'https://www.mapofus.org/marche-italy/', 'title': 'Marche, Italy', 'description': 'Located on the eastern coast of central Italy is Le Marche, a region that covers approximately 3.616 square miles. In size, Marche is the sixth smallest region in Italy and the eighth smallest in population. An interesting fact about Marche, Italy, is tha', 'quality': 8.666077165296546, 'format': 'html', 'details': [[]]}, {'url': 'https://www.toms.com.hr/index.php/toms/article/download/718/591/5704', 'title': 'The Evolution of Italy-Greece Passenger Maritime Transport: a Multi-level Study to Estimat ...
# ***
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='Ancona city population 2023' max_results=10
#
# *** RESULT ***
# [{'url': 'https://en.wikipedia.org/wiki/List_of_mayors_of_Ancona', 'title': 'List of mayors of Ancona', 'description': "The Mayor of Ancona is an elected politician who, along with the Ancona's City Council, is accountable for the strategic government of Ancona in Marche, Italy. The current Mayor is Daniele Silvetti, a member of Forza Italia who took office on 30 May 2023.", 'quality': 6.2182926221192885, 'format': 'html', 'details': [[]]}, {'url': 'http://www.patrickcomerford.com/2023_11_17_archive.html', 'title': 'COMERFORD WAY: Patrick Comerford: 17 November 2023', 'description': 'The Church of San Donato on Via Zamboni in Bologna a reminder of the gates into Bologna’s former Jewish quarter (Photograph: Patrick Comerford) Throughout this week, my morning blog postings have been looking as churches, basilicas and other religious bui', 'quality': 7.500351359569901, 'format': 'html', 'details': [[]]}, {'url': 'http://www.patrickcomerford.com/2023_10_24_archive.html', 'title': 'COMERFORD WAY: Patrick Comerford: 24 October 2023', 'description': 'The school buildings at Gormanston College are typical of mid-1950s architecture are they about to go Photograph: Patrick Comerford)Patrick Comerford I am like anyone and everyone who went to school in Ireland, I imagine, having regular dreams in which I ', 'quality': 7.917719573243023, 'format': 'html', 'details': [[]]}, {'url': 'https://www.davestravelpages.com/patras-port-in-greece/', 'title': 'Patras Ferry Port in Greece - Ferries to Ionian Islands and Italy', 'description': 'The New Port of Patras in Greece acts as a gateway for ferries traveling to and from Italy and other Adriatic destinations. It is also a convenient port for domestic ferries to and from the Greek islands of Kefalonia and Ithaca. This guide to Patras port ', 'quality': 9.053110804841063, 'format': 'html', 'details': [[]]}, {'url': 'https://theava.com/archives/235087', 'title': 'Off the Record (December 29, 2023) – Anderson Valley Advertiser', 'description': "By AVA News Service on December 29, 2023 JOHN SHANDEL OF ALBION Sam Gitchell: There is a huge void in the universe. Albion Icon and the world's best neighbor has passed away at home. Rest in Peace Dear Man. Goodbye John Shandel. He will be dearly missed b", 'quality': 9.378874352691241, 'format': 'html', 'details': [[]]}, {'url': 'https://www.toms.com.hr/index.php/toms/article/download/718/591/5704', 'title': 'The Evolution of Italy-Greece Passenger Maritime Transport: a Multi-level Study to Estimate the Factors Influencing the Deman...', 'description': 'In recent years, the shipping and maritime transport segment has undergone profound changes. Faced with the need to achieve the sustainability goals set by Agenda 2030, different sustainable modes of transport must therefore be evaluated. Passenger transp', 'quality': 9.537735864166105, 'format': 'pdf', 'details': [[]]}, {'url': 'https://www.cruisemapper.com/ports/ancona-port-243', 'title': 'Ancona (Italy) cruise port schedule | CruiseMapper', 'description': "Port Ancona cruise ship schedule shows timetable calendars of all arrival and departure dates by month. The port's schedule lists all ships (in links) with cruises going to or leaving from Ancona, Italy. To see the full itineraries (ports of call dates an", 'quality': 10.012077476395717, 'format': 'html', 'details': [[]]}, {'url': 'https://openjournals.wu-wien.ac.at/ojs/index.php/region/issue/download/30/39', 'title': 'Volume 10, Number 1, 2023 Table of Contents', 'description': '2 M. Kruse, C. Somcutean, J. Wedemeier et al. 2019, McCann, Ortega-Argilés 2013 As the saying goes, all that glitters is not gold but is smart specialisation glitter or gold? And which regions do benefit? Romão (2020) considers economic specialisations ', 'quality': 10.298682312924026, 'format': 'pdf', 'details': [[]]}, {'url': 'https://papers.academic-conferences.org/index.php/ecmlg/issue/download/28/31', 'title': 'Proceedings of the 19th European Conference on Management Lea ...
# ***
# ** CALLING FUNCTION read_website **
# *** ARGS ***
# url='https://www.cruisemapper.com/ports/ancona-port-243'
#
# *** RESULT ***
# 403 Forbidden
#
# Forbidden
# =========
#
# You don't have permission to access this resource.
# ***
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='Ancona Italy population official statistics' max_results=10
#
# *** RESULT ***
# [{'url': 'https://citypopulation.de/en/italy/cities/marche/', 'title': 'Marche (Italy): Provinces, Major Cities & Communes - Population Statistics, Maps, Charts, Weather and Web Information', 'description': 'The population of the provinces of Marche according to census results and latest official estimates.', 'quality': 8.34353246083328, 'format': 'html', 'details': [[]]}, {'url': 'http://citypopulation.de/en/italy/cities/marche/', 'title': 'Marche (Italy): Provinces, Major Cities & Communes - Population Statistics, Maps, Charts, Weather and Web Information', 'description': 'The population of the provinces of Marche according to census results and latest official estimates.', 'quality': 8.479628164647059, 'format': 'html', 'details': [[]]}, {'url': 'https://www.citypopulation.de/en/italy/cities/marche/', 'title': 'Marche (Italy): Provinces, Major Cities & Communes - Population Statistics, Maps, Charts, Weather and Web Information', 'description': 'The population of the provinces of Marche according to census results and latest official estimates.', 'quality': 8.547114740820636, 'format': 'html', 'details': [[]]}, {'url': 'http://italyeconomicinfo.blogspot.com/2008/', 'title': 'Italian Economy Watch: 2008', 'description': 'Edward Hugh is only able to update this blog from time to time, but he does run a lively with plenty of Italy related comment. He also maintains a collection of constantly updated Italy economy charts together with short text updates on a Storify dedicate', 'quality': 9.093051175460515, 'format': 'html', 'details': [[]]}, {'url': 'https://mhealth.jmir.org/2021/7/PDF', 'title': 'JMIR mHealth and uHealth Impact Factor (2024): 5.4 Volume 9 (2021), Issue 7 ISSN 2291-5222 Editor in Chief: Lorraine Buis, Ph...', 'description': 'JMIR MHEALTH AND UHEALTH Fonseka Woo Geriatrics and 61% of children selected that they wore the device “all of As cancer remains a significant disease affecting the geriatric the time they were outside” on a questionnaire following a population, it is nec', 'quality': 10.690672867185958, 'format': 'pdf', 'details': [[]]}, {'url': 'https://ontheworldmap.com/italy/', 'title': 'Italy Map - Geography and Facts | Discover Italy with Detailed Maps', 'description': 'Description: This map shows governmental boundaries of countries; regions, region capitals, islands and major cities in Italy. Size: 1060x1262px 188 Kb Author: Ontheworldmap.com You may download, print or use the above map for educational, personal and no', 'quality': 16.437527232386827, 'format': 'html', 'details': [[]]}, {'url': 'https://www.istrianet.org/istria/non-istrians/burton/works/1877_fiume-port.htm', 'title': 'Istria on the Internet - Cities, Towns and Hamlets - Rijeka / Fiume', 'description': 'Fiume and Her New Port. By George L. Faber,H.B.M. Vice-Consul at Fiume Source: Journal of the Society of Arts, No. 1,303. Vol. XXV, Friday, November 9, 1877, Published by George Bell Sons (London, 1877 pg. 1029-1038 and 1040-1047 A Word to the Reader the ', 'quality': 22.38302928559939, 'format': 'html', 'details': [[]]}, {'url': 'https://www.lofoten-info.no/history.htm', 'title': 'The History of Flakstad & Moskenes, Lofoten', 'description': 'This page provides a brief HISTORYof Flakstad Moskenes, Lofoten Islands The text consists largely of extracts from our fully illustrated book "Guide to the History of Lofoten" which is protected by copyright. The book is available for purchase from our Th', 'quality': 22.38302928559939, 'format': 'html', 'details': [[]]}, {'url': 'https://education.okfn.org/category/data/index.html', 'title': 'data | Open Education Working Group', 'description': '- June 26, 2018 in Guest post by Fontys University of Applied Sciences, the Netherlands The Greek philosopher Pythagoras once said if you want to multiply joy, then you have to share This also applies to data. Who shares data, gets a multitude of joy valu', 'quality': 22.38302928559939, 'format': 'html', 'details': [[]]}, {'url': 'https://worldjusticeproj ...
# ***
# ** CALLING FUNCTION read_website **
# *** ARGS ***
# url='https://www.citypopulation.de/en/italy/cities/marche/'
#
# *** RESULT ***
# Marche (Italy): Provinces, Major Cities & Communes - Population Statistics, Maps, Charts, Weather and Web Information
#
#
#
#
# [Home](/) → [Europe](/en/europe/) → [Italy](/en/italy/)
#
# [![Marche (Italy) Map](/images/smaps/italy-marche.png)](javascript:openMap())
#
# [Italy](/en/italy/): Marche
# ===========================
#
# Marche Region
#
# Provinces
# ---------
#
# The population of the provinces of Marche according to census results and latest official estimates.
#
# | [Name](javascript:sort('tl',0,false)) | [Abbr.](javascript:sort('tl',1,false)) | [Status](javascript:sort('tl',2,false)) | [Capital](javascript:sort('tl',3,false)) | [Area](javascript:sort('tl',4,true) "Sort") A (km²) | [Population](javascript:sort('tl',5,true) "Sort") Census (C) 1981-10-25 | [Population](javascript:sort('tl',6,true) "Sort") Census (C) 1991-10-20 | [Population](javascript:sort('tl',7,true) "Sort") Census (C) 2001-10-21 | [Population](javascript:sort('tl',8,true) "Sort") Census (C) 2011-10-09 | [Population](javascript:sort('tl',9,true) "Sort") Census (C) 2021-12-31 | [Population](javascript:sort('tl',10,true) "Sort") Estimate (Ep) 2025-01-01 |  |  |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | [Ancona](javascript:sym(7778)) |  | Prov | Ancona | 1,963 | 433,417 | 437,263 | 448,473 | 473,865 | 461,687 | 461,645 | 196300 | [→](/en/italy/admin/marche/042__ancona/) |
# | [Ascoli Piceno](javascript:sym(7780)) |  | Prov | Ascoli Piceno | 1,228 | 192,054 | 197,811 | 203,153 | 210,407 | 202,365 | 200,400 | 122800 | [→](/en/italy/admin/marche/044__ascoli_piceno/) |
# | [Fermo](javascript:sym(8353)) |  | Prov | Fermo | 863 | 160,513 | 162,671 | 166,218 | 174,857 | 168,294 | 167,100 | 86300 | [→](/en/italy/admin/marche/109__fermo/) |
# | [Macerata](javascript:sym(7779)) |  | Prov | Macerata | 2,779 | 292,932 | 295,481 | 301,523 | 319,607 | 304,986 | 302,309 | 277900 | [→](/en/italy/admin/marche/043__macerata/) |
# | [Pesaro e Urbino](javascript:sym(7777)) |  | Prov | Pesaro | 2,511 | 313,897 | 316,650 | 331,364 | 359,963 | 349,818 | 349,798 | 251100 | [→](/en/italy/admin/marche/041__pesaro_e_urbino/) |
# | [Marche](javascript:sym(276)) | MAR | Reg | Ancona | 9,344 | 1,392,813 | 1,409,876 | 1,450,731 | 1,538,699 | 1,487,150 | 1,481,252 | 934400 | [→](/en/italy/admin/11__marche/) |
# |  |  |  |  |  |  |  |  |  |  |  |  |  |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Italy | ITA | Rep | Roma | 302,068 | 56,556,911 | 56,778,031 | 56,995,744 | 59,433,744 | 59,030,133 | 58,934,177 |  | [→](/en/italy/admin/) |
#
# * Istituto Nazionale di Statistica Italia.
#
# Major Cities
# ------------
#
# |  | Name | Population Estimate (Ep) 2025-01-01 |
# | --- | --- | --- |
# | 1 | [Ancona](javascript:sym(3224,1,1)) | 99,469 |
# | 2 | [Pesaro](javascript:sym(3306,1,1)) | 95,360 |
# | 3 | [Fano](javascript:sym(3267,1,1)) | 59,907 |
# | 4 | [San Benedetto del Tronto](javascript:sym(8452,1,1)) | 47,019 |
# | 5 | [Ascoli Piceno](javascript:sym(3227,1,1)) | 45,310 |
# | 6 | [Senigallia](javascript:sym(8458,1,1)) | 43,815 |
# | 7 | [Civitanova Marche](javascript:sym(8408,1,1)) | 41,915 |
# | 8 | [Macerata](javascript:sym(8428,1,1)) | 40,623 |
#
# Contents: Cities & Communes
# ---------------------------
#
# The population of all cities and communes in Marche with more than 20,000 inhabitants according to census results and latest official estimates.
#
# | [Name](javascript:sort('ts',0,false)) | [Population](javascript:sort('ts',1,true,0) "Sort") Census (C) 1981-10-25 | [Population](javascript:sort('ts',2,true,0) "Sort") Census (C) 1991-10-20 | [Population](javascript:sort('ts',3,true,0) "Sort") Census (C) 2001-10-21 | [Population](javascript:sort('ts',4,true,0) "Sort") Census (C) 2011-10-09 | [Population](javascript:sort('ts',5,true,0) "Sort") Census (C) 2021-12-31 | [Population](javascript:sort('ts',6,true,0) "Sort") Estimate (Ep) 2025-01-01 | Area |  |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | [Ancona](javascript:sym(3224)) | 106,498 | 101,285 | 100,507 | 100,497 | 98,402 | 99,469 | 12487 | [→](/en/italy/marche/ancona/042002__ancona/) |
# | [Ascoli Piceno](javascript:sym(3227)) | 54,298 | 53,591 | 51,375 | 49,958 | 46,085 | 45,310 | 15802 | [→](/en/italy/marche/ascoli_piceno/044007__ascoli_piceno/) |
# | [Civitanova Marche](javascript:sym(8408)) | 36,187 | 37,260 | 38,299 | 40,217 | 41,768 | 41,915 | 4607 | [→](/en/italy/marche/macerata/043013__civitanova_marche/) |
# | [Fabriano](javascript:sym(16801)) | 28,727 | 28,721 | 30,019 | 31,020 | 29,070 | 28,648 | 27208 | [→](/en/italy/marche/ancona/042017__fabriano/) |
# | [Falconara Marittima](javascript:sym(16803)) | 29,122 | 30,105 | 28,349 | 26,710 | 25,576 | 25,887 | 2581 | [→](/en/italy/marche/ancona/042018__falconara_marittima/) |
# | [Fano](javascript:sym(3267)) | 52,116 | 53,909 | 57,529 | 62,901 | 59,926 | 59,907 | 12032 | [→](/en/italy/marche/pesaro_e_urbino/041013__fano/) |
# | [Fermo](javascript:sym(8416)) | 35,119 | 35,111 | 35,502 | 37,016 | 35,923 | 35,835 | 12453 | [→](/en/italy/marche/fermo/109006__fermo/) |
# | [Jesi](javascript:sym(8424)) | 40,954 | 40,156 | 39,224 | 40,303 | 39,217 | 39,453 | 10890 | [→](/en/italy/marche/ancona/042021__jesi/) |
# | [Macerata](javascript:sym(8428)) | 43,782 | 43,040 | 40,875 | 42,019 | 40,503 | 40,623 | 9253 | [→](/en/italy/marche/macerata/043023__macerata/) |
# | [Osimo](javascript:sym(16802)) | 26,109 | 27,938 | 29,431 | 33,991 | 34,792 | 34,820 | 10674 | [→](/en/italy/marche/ancona/042034__osimo/) |
# | [Pesaro](javascript:sym(3306)) | 91,292 | 89,682 | 92,382 | 95,923 | 95,670 | 95,360 | 15281 | [→](/en/italy/marche/pesaro_e_urbino/041044__pesaro/) |
# | [Porto Sant'Elpidio](javascript:sym(16804)) | 19,646 | 21,112 | 22,752 | 25,324 | 25,757 | 25,801 | 1813 | [→](/en/italy/marche/fermo/109034__porto_santelpidio/) |
# | [Recanati](javascript:sym(18958)) | 18,510 | 19,359 | 20,050 | 21,416 | 20,697 | 20,630 | 10346 | [→](/en/italy/marche/macerata/043044__recanati/) |
# | [San Benedetto del Tronto](javascript:sym(8452)) | 44,773 | 42,693 | 45,054 | 46,963 | 47,000 | 47,019 | 2541 | [→](/en/italy/marche/ascoli_piceno/044066__san_benedetto_del_tronto/) |
# | [Senigallia](javascript:sym(8458)) | 40,135 | 41,144 | 41,550 | 44,361 | 44,245 | 43,815 | 11777 | [→](/en/italy/marche/ancona/042045__senigallia/) |
# | [Tolentino](javascript:sym(27644)) | 18,053 | 18,346 | 18,649 | 20,336 | 18,142 | 17,544 | 9512 | [→](/en/italy/marche/macerata/043053__tolentino/) |
#
# * Istituto Nazionale di Statistica Italia.
#
# Population Structure
# --------------------
#
# Further information about the population structure.
#
# | Gender (R 2025) | |
# | --- | --- |
# | Males | 726,773 |
# | Females | 754,479 |
#
# | Age Groups (R 2025) | |
# | --- | --- |
# | 0-17 years | 209,900 |
# | 18-64 years | 878,074 |
# | 65+ years | 393,278 |
#
# | Age Distribution (R 2025) | |
# | --- | --- |
# | 90+ years | 26,835 |
# | 80-89 years | 104,851 |
# | 70-79 years | 163,908 |
# | 60-69 years | 210,295 |
# | 50-59 years | 237,040 |
# | 40-49 years | 196,035 |
# | 30-39 years | 156,255 |
# | 20-29 years | 147,821 |
# | 10-19 years | 137,120 |
# | 0-9 years | 101,092 |
#
# | Citizenship (R 2025) | |
# | --- | --- |
# | Italy | 1,344,726 |
# | Foreign Citizenship | 136,526 |
#
# Google Search for: Hotels - Restaurants - Shopping - Sights - Maps - Images
#
# Wikipedia - Google: Satellite Map / Street Map - Open Street Map
# ***
# Response: The population of the city of Ancona, Italy, as of the latest official estimate (2025-01-01), is **99,469**.
#
# For more details, you can refer to the [source](https://www.citypopulation.de/en/italy/cities/marche/).
